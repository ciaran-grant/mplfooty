# %%
import sys
sys.path.append("..")
from afl_plots.pitch import AFLPitch

import numpy as np

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
pitch = AFLPitch(pitch_width=135, pitch_length=165)
fig, ax = pitch.draw()
x = np.random.uniform(low=-80, high=80, size=100)
y= np.random.uniform(low=-65, high=65, size=100)
pitch.scatter(x, y, ax=ax)

# %%
pitch = AFLPitch(pitch_width=135, pitch_length=165)
fig, ax = pitch.draw()
x = np.random.uniform(low=-80, high=80, size=100)
y= np.random.uniform(low=-65, high=65, size=100)
pitch.scatter(x, y, marker = "x", color = "red", ax=ax)
