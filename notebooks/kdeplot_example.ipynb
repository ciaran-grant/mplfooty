# %%
import sys
sys.path.append(r"/Users/ciaran/Documents/Projects/AFL/git-repositories/mplfooty/mplfooty/")

from mplfooty.pitch import VerticalPitch, Pitch
import numpy as np

# %load_ext autoreload
# %autoreload 2
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
pitch = Pitch(pitch_width=135, pitch_length=165, line_zorder=2, axis = True, label=True)
fig, ax = pitch.draw()
x = np.random.uniform(low=-100/2, high=100/2, size=36)
y = np.random.uniform(low=-90/2, high=90/2, size=36)
pitch.kdeplot(x, y, ax=ax)
# Out:
# <Axes: >

# %%
pitch = Pitch(pitch_width=135, pitch_length=165, line_zorder=2)
fig, ax = pitch.draw()
x = np.random.uniform(low=-100/2, high=100/2, size=36)
y = np.random.uniform(low=-90/2, high=90/2, size=36)
pitch.kdeplot(x, y, ax=ax, thresh=0, fill = True, color = "red", levels=100)
# Out:
# <Axes: >

# %%
pitch = VerticalPitch(pitch_width=135, pitch_length=165, line_zorder=2)
fig, ax = pitch.draw()
pitch.kdeplot(x, y, ax=ax, thresh=0, fill = True, color = "red", levels=100)
# Out:
# <Axes: >
