# %%
import sys
sys.path.append("..")
from afl_plots.pitch import AFLPitch

import numpy as np

# %load_ext autoreload
# %autoreload 2
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
pitch = AFLPitch(pitch_width=135, pitch_length=165, line_zorder=2, axis = True, label=True)
fig, ax = pitch.draw()
x = np.random.uniform(low=-40, high=40, size=100)
y= np.random.uniform(low=-20, high=20, size=100)
pitch.kdeplot(x, y, ax=ax)
# Out:
# <Axes: >

# %%
pitch = AFLPitch(pitch_width=135, pitch_length=165, line_zorder=2, line_colour="#000009", axis = True, label=True)
fig, ax = pitch.draw()
x = np.random.uniform(low=-82.5, high=82.5, size=20)
y= np.random.uniform(low=-82.5, high=82.5, size=20)
pitch.kdeplot(x, y, ax=ax, thresh=0,
              fill = True, color = "red",
              levels=50
              )
# Out:
# <Axes: >
