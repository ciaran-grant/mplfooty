# %%
import sys
sys.path.append("..")
from afl_plots.pitch import AFLPitch

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
pitch = AFLPitch(pitch_width=135, pitch_length=165,
                 axis=True, tick=True, label=True)

# %%
pitch.draw()
# Out:
# (<Figure size 640x480 with 1 Axes>, <Axes: >)

# %%
pitch = AFLPitch(pitch_width=135, pitch_length=165)
pitch.draw(ncols=2, nrows=2)
# Out:
# (<Figure size 640x480 with 4 Axes>,
#  array([[<Axes: >, <Axes: >],
#         [<Axes: >, <Axes: >]], dtype=object))

# %%
pitch = AFLPitch(pitch_width=135, pitch_length=165, half=True)
pitch.draw()
# Out:
# (<Figure size 640x480 with 1 Axes>, <Axes: >)

# %%
pitch = AFLPitch(pitch_width=135, pitch_length=165, half=True)
pitch.draw(nrows=2, ncols=2)
# Out:
# (<Figure size 640x480 with 4 Axes>,
#  array([[<Axes: >, <Axes: >],
#         [<Axes: >, <Axes: >]], dtype=object))
