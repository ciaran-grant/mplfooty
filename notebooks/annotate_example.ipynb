# %%
from mplfooty.pitch import VerticalPitch, Pitch
import numpy as np

# %load_ext autoreload
# %autoreload 2
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
pitch = Pitch(pitch_width=135, pitch_length=165)
fig, ax = pitch.draw()
pitch.annotate(text = "Test", xytext = (-30,0), xy=(40,40), ha='center', va='center', ax=ax, arrowprops=dict(facecolor="black"))
# Out:
# Text(-30, 0, 'Test')

# %%
pitch = VerticalPitch(pitch_width=135, pitch_length=165)
fig, ax = pitch.draw()
pitch.annotate(text = "Test", xytext = (-30,0), xy=(40,40), ha='center', va='center', ax=ax, arrowprops=dict(facecolor="black"))
# Out:
# Text(0, -30, 'Test')
