# %%
from mplfooty.pitch import VerticalPitch, Pitch
import numpy as np

# %load_ext autoreload
# %autoreload 2

# %%
pitch = Pitch(pitch_width=135, pitch_length=165, line_zorder=2, line_colour="black")
fig, ax = pitch.draw()

X, Y = np.meshgrid(np.linspace(-100, 100, num=100), np.linspace(-100, 100, num=100))
Z = np.random.normal(0.5, 0.2, (100,100))
pitch.contour(X, Y, Z, ax=ax, levels=10, cmap='seismic', vmin=0, vmax=1, zorder=1, alhpa = 0.5)
# Out:
# /Users/ciaran/opt/anaconda3/envs/afl-plots-env/lib/python3.9/site-packages/mplfooty/pitch_plot.py:999: UserWarning: The following kwargs were not used by contour: 'alhpa'
#   cfs = ax.contourf(X, Y, Z, **kwargs)

# %%
pitch = VerticalPitch(pitch_width=135, pitch_length=165, line_zorder=2, line_colour="black")
fig, ax = pitch.draw()

X, Y = np.meshgrid(np.linspace(-100, 100, num=100), np.linspace(-100, 100, num=100))
Z = np.random.normal(0.5, 0.2, (100,100))
pitch.contour(X, Y, X, ax=ax, levels=10, cmap='seismic', vmin=0, vmax=1, zorder=1, alhpa = 0.5)
# Out:
# /Users/ciaran/opt/anaconda3/envs/afl-plots-env/lib/python3.9/site-packages/mplfooty/pitch_plot.py:999: UserWarning: The following kwargs were not used by contour: 'alhpa'
#   cfs = ax.contourf(X, Y, Z, **kwargs)
# /Users/ciaran/opt/anaconda3/envs/afl-plots-env/lib/python3.9/site-packages/mplfooty/pitch_plot.py:1001: UserWarning: The following kwargs were not used by contour: 'alhpa'
#   cfs = ax.contourf(Y, X, Z, **kwargs)
